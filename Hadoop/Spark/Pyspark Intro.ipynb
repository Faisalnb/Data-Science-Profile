# %%
df= spark.read.csv('/FileStore/shared_uploads/faizalnajeeb761@gmail.com/IRIS.csv',header=True,inferSchema=True)

# %%
df.rdd.map(list).take(10)
# Out:
# Out[3]: [['5.1', 3.5, '1.4', 0.2, 'Iris-setosa'],
#  ['4.9', 3.0, '1.4', 0.2, 'Iris-setosa'],
#  ['4.7', 3.2, '1.3', 0.2, 'Iris-setosa'],
#  ['4.6', 3.1, '1.5', 0.2, 'Iris-setosa'],
#  ['5', 3.6, '1.4', 0.2, 'Iris-setosa'],
#  ['5.4', 3.9, '1.7', 0.4, 'Iris-setosa'],
#  ['4.6', 3.4, '1.4', 0.3, 'Iris-setosa'],
#  ['5', 3.4, '1.5', 0.2, 'Iris-setosa'],
#  ['4.4', 2.9, 'text2', 0.2, 'Iris-setosa'],
#  ['4.9', 3.1, '1.5', 0.1, 'text3']]

# %%
df.columns
# Out:
# Out[5]: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
df.show(5)
# Out:
# +------------+-----------+------------+-----------+-----------+
# |sepal_length|sepal_width|petal_length|petal_width|    species|
# +------------+-----------+------------+-----------+-----------+
# |         5.1|        3.5|         1.4|        0.2|Iris-setosa|
# |         4.9|        3.0|         1.4|        0.2|Iris-setosa|
# |         4.7|        3.2|         1.3|        0.2|Iris-setosa|
# |         4.6|        3.1|         1.5|        0.2|Iris-setosa|
# |           5|        3.6|         1.4|        0.2|Iris-setosa|
# +------------+-----------+------------+-----------+-----------+
# only showing top 5 rows

# %%
df.collect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-3659405155793364> in <module>
# ----> 1 df.collect(2)
#
# TypeError: collect() takes 1 positional argument but 2 were given

# %%
df.select('sepal_length','species').show(5)
# Out:
# +------------+-----------+
# |sepal_length|    species|
# +------------+-----------+
# |         5.1|Iris-setosa|
# |         4.9|Iris-setosa|
# |         4.7|Iris-setosa|
# |         4.6|Iris-setosa|
# |           5|Iris-setosa|
# +------------+-----------+
# only showing top 5 rows

# %%
df.schema
# Out:
# Out[12]: StructType(List(StructField(sepal_length,StringType,true),StructField(sepal_width,DoubleType,true),StructField(petal_length,StringType,true),StructField(petal_width,DoubleType,true),StructField(species,StringType,true)))

# %%
df.drop('petal_length').show(5)
# Out:
# +------------+-----------+-----------+-----------+
# |sepal_length|sepal_width|petal_width|    species|
# +------------+-----------+-----------+-----------+
# |         5.1|        3.5|        0.2|Iris-setosa|
# |         4.9|        3.0|        0.2|Iris-setosa|
# |         4.7|        3.2|        0.2|Iris-setosa|
# |         4.6|        3.1|        0.2|Iris-setosa|
# |           5|        3.6|        0.2|Iris-setosa|
# +------------+-----------+-----------+-----------+
# only showing top 5 rows

# %%
df= df.select(df.sepal_length.cast("float"),df.petal_length.cast('float'),df.sepal_width.cast('float'),df.petal_width.cast('float'),df.species)

# %%
idata.schema
# Out:
# Out[19]: StructType(List(StructField(sepal_length,FloatType,true)))

# %%
df.filter("species=='Iris-virginica'").show(5)
# Out:
# +------------+-----------+------------+-----------+--------------+
# |sepal_length|sepal_width|petal_length|petal_width|       species|
# +------------+-----------+------------+-----------+--------------+
# |         6.3|        3.3|           6|        2.5|Iris-virginica|
# |         5.8|        2.7|         5.1|        1.9|Iris-virginica|
# |         7.1|        3.0|         5.9|        2.1|Iris-virginica|
# |         6.3|        2.9|         5.6|        1.8|Iris-virginica|
# |         6.5|        3.0|         5.8|        2.2|Iris-virginica|
# +------------+-----------+------------+-----------+--------------+
# only showing top 5 rows

# %%
df[df.species.isin('Iris-virginica')].show()
# Out:
# +------------+-----------+------------+-----------+--------------+
# |sepal_length|sepal_width|petal_length|petal_width|       species|
# +------------+-----------+------------+-----------+--------------+
# |         6.3|        3.3|           6|        2.5|Iris-virginica|
# |         5.8|        2.7|         5.1|        1.9|Iris-virginica|
# |         7.1|        3.0|         5.9|        2.1|Iris-virginica|
# |         6.3|        2.9|         5.6|        1.8|Iris-virginica|
# |         6.5|        3.0|         5.8|        2.2|Iris-virginica|
# |         7.6|        3.0|         6.6|        2.1|Iris-virginica|
# |         4.9|        2.5|         4.5|        1.7|Iris-virginica|
# |         7.3|        2.9|         6.3|        1.8|Iris-virginica|
# |         6.7|        2.5|         5.8|        1.8|Iris-virginica|
# |         7.2|        3.6|         6.1|        2.5|Iris-virginica|
# |         6.5|        3.2|         5.1|        2.0|Iris-virginica|
# ...

# %%
df.select('species').distinct().count()
# Out:
# Out[34]: 5

# %%
df.groupBy('species').agg({ 'sepal_length':'min'}).show()
# Out:
# +---------------+-----------------+
# |        species|min(sepal_length)|
# +---------------+-----------------+
# | Iris-virginica|              4.9|
# |    Iris-setosa|              4.3|
# |          text3|              4.9|
# |Iris-versicolor|              4.9|
# |          text4|              5.1|
# +---------------+-----------------+

# %%
df.cube('species').min().show()
# Out:
# +---------------+-----------------+-----------------+----------------+----------------+
# |        species|min(sepal_length)|min(petal_length)|min(sepal_width)|min(petal_width)|
# +---------------+-----------------+-----------------+----------------+----------------+
# | Iris-virginica|              4.9|              4.5|             2.2|             1.4|
# |    Iris-setosa|              4.3|              1.0|             2.3|             0.1|
# |           null|              4.3|              1.0|             2.0|             0.1|
# |Iris-versicolor|              4.9|              3.0|             2.0|             1.0|
# |          text3|              4.9|              1.5|             3.1|             0.1|
# |          text4|              5.1|             null|             3.8|             0.3|
# +---------------+-----------------+-----------------+----------------+----------------+

# %%
df.describe().show()
# Out:
# +-------+------------------+-------------------+------------------+------------------+-----------+
# |summary|      sepal_length|        sepal_width|      petal_length|       petal_width|    species|
# +-------+------------------+-------------------+------------------+------------------+-----------+
# |  count|               150|                150|               150|               150|        150|
# |   mean| 5.850335570469801| 3.0540000000000007| 3.789864864864867|1.1986666666666672|       null|
# | stddev|0.8263910599279832|0.43359431136217375|1.7555641326340479|0.7631607417008414|       null|
# |    min|               4.3|                2.0|                 1|               0.1|Iris-setosa|
# |    max|             text1|                4.4|             text5|               2.5|      text4|
# +-------+------------------+-------------------+------------------+------------------+-----------+

# %%
df.createOrReplaceTempView('df_temp')

# %%
sqlContext.tables().show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |        |  df_temp|       true|
# +--------+---------+-----------+
