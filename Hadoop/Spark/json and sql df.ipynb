# %%
from pyspark.sql.functions import explode ,col

# %%
details= """
[
 {
   "sepal_length": 5.1,
   "sepal_width": 3.5,
   "petal_length": "1.4",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 4.9,
   "sepal_width": 3,
   "petal_length": "1.4",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 4.7,
   "sepal_width": 3.2,
   "petal_length": "1.3",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 4.6,
   "sepal_width": 3.1,
   "petal_length": "1.5",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 5,
   "sepal_width": 3.6,
   "petal_length": "1.4",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 5.4,
   "sepal_width": 3.9,
   "petal_length": "1.7",
   "petal_width": 0.4,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 4.6,
   "sepal_width": 3.4,
   "petal_length": "1.4",
   "petal_width": 0.3,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 5,
   "sepal_width": 3.4,
   "petal_length": "1.5",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 4.4,
   "sepal_width": 2.9,
   "petal_length": "text2",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 },
 {
   "sepal_length": 4.9,
   "sepal_width": 3.1,
   "petal_length": "1.5",
   "petal_width": 0.1,
   "species": "text3"
 },
 {
   "sepal_length": 5.4,
   "sepal_width": 3.7,
   "petal_length": "1.5",
   "petal_width": 0.2,
   "species": "Iris-setosa"
 }
]"""

# %%
details ="""
const express = require('express')
const app = express()
const port = 3000

app.get('/', (req, res) => res.json([{
  name: 'faisal',
  email: 'faisal@gmail.com'
}]))

app.listen(port, () => console.log(`Example app listening on port ${port}`))
"""

# %%
dbutils.fs.put('/FileStore/tables/details.json',details,True)
# Out:
# Wrote 245 bytes.
# Out[18]: True

# %%
df= spark.read.option('multiline','true').json('/FileStore/tables/details.json')

# %%
display(df)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-2239262832881733> in <module>
# ----> 1 display(df)
#
# /databricks/python_shell/dbruntime/display.py in display(self, input, *args, **kwargs)
#      78                     raise Exception('Triggers can only be set for streaming queries.')
#      79
# ---> 80                 self.add_custom_display_data("table", input._jdf)
#      81
#      82         elif isinstance(input, list):
#
# /databricks/python_shell/dbruntime/display.py in add_custom_display_data(self, data_type, data)
#      35     def add_custom_display_data(self, data_type, data):
#      36         custom_display_key = str(uuid.uuid4())
# ---> 37         return_code = self.entry_point.addCustomDisplayData(custom_display_key, data_type, data)
#      38         ip_display({"application/vnd.databricks.v1+display": custom_display_key}, raw=True)
# ...

# %%
# %sql
Create or replace temporary view details_view
using json
options(path='/FileStore/tables/details.json',multiline=True)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from details_view
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.explode(col'species',)

# %%
## read using sql

# %%
# %sql
create database flowers ;
create table flowers.table001
using delta
options(
path '/dbfs/FileStore/tables/coalesce/part-00000-tid-7776962098476730170-f94c016b-f6ce-426c-b52e-89d06546b46b-32-1-c000.snappy.parquet'
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.AnalysisException:
# You are trying to create an external table `spark_catalog`.`flowers`.`table001`
# from `dbfs:/dbfs/FileStore/tables/coalesce/part-00000-tid-7776962098476730170-f94c016b-f6ce-426c-b52e-89d06546b46b-32-1-c000.snappy.parquet` using Databricks Delta, but the schema is not specified when the
# input path is empty.
#
# To learn more about Delta, see https://docs.databricks.com/delta/index.html
#
# 	at com.databricks.sql.transaction.tahoe.DeltaErrors$.createExternalTableWithoutSchemaException(DeltaErrors.scala:952)
# ...

# %%
# %sql drop database flowers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
