# %% [markdown]
# <h1>Evaluate the dataset containing the GDPs of different countries to:<h1>
#
# <h4><ol>
# <li>Find and print the name of the country with the highest GDP</li>
#
# <li>Find and print the name of the country with the lowest GDP</li>
#
# <li>Print out text and input values iteratively</li>
#
# <li>Print out the entire list of the countries with their GDPs</li>
#
# <li>Print the highest GDP value, lowest GDP value, mean GDP value, standardized GDP value, and the sum of all the GDPs</li>
# </ol><h4>

# %%
# prog to find min,max and std values of gdp .Also display countries with min and max gdp/capita .show data in iterative format

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_excel("D:\\Data science with Python\\Assignments\\GDP\\GDP for countries in 2017.xlsx")

# %%
df.head()
# Out:
#    #     Country  GDP per capita
# 0  1       Qatar          128647
# 1  2       Macao          115367
# 2  3  Luxembourg          107641
# 3  4   Singapore           94105
# 4  5      Brunei           79003

# %%
df1=np.array(df)

# %%
countries=df1[0:100,1];countries
# Out:
# array(['Qatar', 'Macao', 'Luxembourg', 'Singapore', 'Brunei', 'Ireland',
#        'United Arab Emirates', 'Kuwait', 'Switzerland', 'San Marino',
#        'Norway', 'Hong Kong', 'United States', 'Iceland', 'Netherlands',
#        'Denmark', 'Saudi Arabia', 'Austria', 'Germany', 'Sweden',
#        'Australia', 'Belgium', 'Bahrain', 'Canada', 'Finland',
#        'United Kingdom', 'France', 'Japan', 'Oman', 'Italy', 'Malta',
#        'New Zealand', 'Aruba', 'Spain', 'Israel', 'South Korea',
#        'Czech Republic (Czechia)', 'Slovenia', 'Cyprus', 'Estonia',
#        'Lithuania', 'Portugal', 'Slovakia', 'Trinidad and Tobago',
#        'Bahamas', 'Poland', 'Malaysia', 'Seychelles', 'Hungary',
#        'Saint Kitts & Nevis', 'Greece', 'Latvia', 'Turkey', 'Romania',
#        'Kazakhstan', 'Croatia', 'Russia', 'Chile', 'Panama',
#        'Equatorial Guinea', 'Antigua and Barbuda', 'Uruguay', 'Mauritius',
#        'Bulgaria', 'Iran', 'Argentina', 'Libya', 'Montenegro', 'Belarus',
# ...

# %%
gdp_per_capita=df1[0:100,2];gdp_per_capita
# Out:
# array([128647, 115367, 107641, 94105, 79003, 76745, 74035, 72096, 66307,
#        63549, 62183, 61671, 59928, 55322, 54422, 54356, 53893, 53879,
#        52556, 51405, 49378, 49367, 47708, 46510, 46344, 44920, 44033,
#        42067, 41331, 40924, 40797, 40748, 39493, 39037, 38868, 38824,
#        38020, 36387, 36012, 33448, 33253, 32554, 32371, 31645, 30495,
#        29924, 29511, 29328, 28799, 28636, 28583, 28362, 28002, 26660,
#        26491, 26296, 25763, 24747, 24521, 24439, 23522, 22610, 22356,
#        20948, 20885, 20829, 19673, 19355, 18896, 18656, 18559, 18113,
#        18031, 17910, 17450, 17110, 17024, 16935, 16842, 16688, 16064,
#        15553, 15432, 15293, 15290, 15191, 15156, 14854, 14513, 14503,
#        13986, 13526, 13463, 13109, 13108, 12946, 12943, 12863, 12310,
#        11936], dtype=object)

# %%
#countries with min and max gdp

# %%
min_gdp_per_capita=np.min([gdp_per_capita]);min_gdp_per_capita
# Out:
# 11936

# %%
df_gdp=[128647, 115367, 107641, 94105, 79003, 76745, 74035, 72096, 66307,
       63549, 62183, 61671, 59928, 55322, 54422, 54356, 53893, 53879,
       52556, 51405, 49378, 49367, 47708, 46510, 46344, 44920, 44033,
       42067, 41331, 40924, 40797, 40748, 39493, 39037, 38868, 38824,
       38020, 36387, 36012, 33448, 33253, 32554, 32371, 31645, 30495,
       29924, 29511, 29328, 28799, 28636, 28583, 28362, 28002, 26660,
       26491, 26296, 25763, 24747, 24521, 24439, 23522, 22610, 22356,
       20948, 20885, 20829, 19673, 19355, 18896, 18656, 18559, 18113,
       18031, 17910, 17450, 17110, 17024, 16935, 16842, 16688, 16064,
       15553, 15432, 15293, 15290, 15191, 15156, 14854, 14513, 14503,
       13986, 13526, 13463, 13109, 13108, 12946, 12943, 12863, 12310,
       11936]
df_countries=['Qatar', 'Macao', 'Luxembourg', 'Singapore', 'Brunei', 'Ireland',
       'United Arab Emirates', 'Kuwait', 'Switzerland', 'San Marino',
       'Norway', 'Hong Kong', 'United States', 'Iceland', 'Netherlands',
       'Denmark', 'Saudi Arabia', 'Austria', 'Germany', 'Sweden',
       'Australia', 'Belgium', 'Bahrain', 'Canada', 'Finland',
       'United Kingdom', 'France', 'Japan', 'Oman', 'Italy', 'Malta',
       'New Zealand', 'Aruba', 'Spain', 'Israel', 'South Korea',
       'Czech Republic (Czechia)', 'Slovenia', 'Cyprus', 'Estonia',
       'Lithuania', 'Portugal', 'Slovakia', 'Trinidad and Tobago',
       'Bahamas', 'Poland', 'Malaysia', 'Seychelles', 'Hungary',
       'Saint Kitts & Nevis', 'Greece', 'Latvia', 'Turkey', 'Romania',
       'Kazakhstan', 'Croatia', 'Russia', 'Chile', 'Panama',
       'Equatorial Guinea', 'Antigua and Barbuda', 'Uruguay', 'Mauritius',
       'Bulgaria', 'Iran', 'Argentina', 'Libya', 'Montenegro', 'Belarus',
       'Mexico', 'Barbados', 'Gabon', 'Turkmenistan', 'Thailand',
       'Azerbaijan', 'Costa Rica', 'Botswana', 'Iraq', 'China',
       'Maldives', 'Dominican Republic', 'Brazil', 'Serbia', 'Algeria',
       'North Macedonia', 'Suriname', 'Grenada', 'Palau', 'Lebanon',
       'Colombia', 'Saint Lucia', 'South Africa', 'Peru', 'Paraguay',
       'Bosnia and Herzegovina', 'Mongolia', 'Albania', 'Sri Lanka',
       'Indonesia', 'Tunisia']
i1=df_gdp.index(11936);i1
# Out:
# 99

# %%
country_min_gdp_per_capita=countries[99];country_min_gdp_per_capita
# Out:
# 'Tunisia'

# %%
max_gdp_per_capita=np.max([gdp_per_capita]);max_gdp_per_capita
# Out:
# 128647

# %%
i2=df_gdp.index(128647);i2
# Out:
# 0

# %%
country_max_gdp_per_capita=countries[0];country_max_gdp_per_capita
# Out:
# 'Qatar'

# %%
#printing iterative values for country with gdp
for country in countries:
    print()

# %%
for i in df_countries:
  for j in df_gdp:
    print(i,'GDP per capita is',j)
# Out:
# Qatar GDP per capita is 128647
# Qatar GDP per capita is 115367
# Qatar GDP per capita is 107641
# Qatar GDP per capita is 94105
# Qatar GDP per capita is 79003
# Qatar GDP per capita is 76745
# Qatar GDP per capita is 74035
# Qatar GDP per capita is 72096
# Qatar GDP per capita is 66307
# Qatar GDP per capita is 63549
# Qatar GDP per capita is 62183
# Qatar GDP per capita is 61671
# Qatar GDP per capita is 59928
# Qatar GDP per capita is 55322
# Qatar GDP per capita is 54422
# Qatar GDP per capita is 54356
# Qatar GDP per capita is 53893
# Qatar GDP per capita is 53879
# Qatar GDP per capita is 52556
# Qatar GDP per capita is 51405
# Qatar GDP per capita is 49378
# Qatar GDP per capita is 49367
# Qatar GDP per capita is 47708
# Qatar GDP per capita is 46510
# Qatar GDP per capita is 46344
# Qatar GDP per capita is 44920
# Qatar GDP per capita is 44033
# Qatar GDP per capita is 42067
# Qatar GDP per capita is 41331
# Qatar GDP per capita is 40924
# Qatar GDP per capita is 40797
# ...

# %%
#mean ,median ,mode ,std values of gdp

# %%
print('minimum value of GDP is',min(gdp_per_capita))
# Out:
# minimum value of GDP is 11936

# %%
print ('mean value of GDP is ',np.mean(gdp_per_capita))
# Out:
# mean value of GDP is  35061.37

# %%
print ('maximum value of GDP is ',max(gdp_per_capita))
# Out:
# maximum value of GDP is  128647

# %%
print ('std value of GDP is ', np.std(gdp_per_capita))
# Out:
# std value of GDP is  23033.85712278992
