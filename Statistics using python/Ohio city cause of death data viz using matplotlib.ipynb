# %% [markdown]
# <h2>You have been provided with a dataset that lists Ohio State’s leading causes of death from the year 2012.<h2>
#
# <h3>Using the two data points:
# <ol><li>Cause of deaths and</li>
# <li>Percentile</li>
# <li>Draw a pie chart to visualize the dataset</li><ol>
# <h3>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
labels='Chronic Disease', 'Unintetional Injuries', 'Alzheimers', 'Infuenza & Pneumonia', 'Sepsis','Others'
sizes=[62, 5, 4, 2, 1 , 26]

# %%
 # include plot area
plt.figure(figsize=(10,10))
#enter givn data
plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=70)
#set equal axeses
plt.axis('equal')
#enter title for plot
plt.title('Cause of Deaths,Ohio :2012')
#show
plt.show()
